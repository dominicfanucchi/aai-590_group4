# %% [markdown]
# # **Manual Labeling with Label Studio**

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import shutil
import cv2

# %%
# setting the base directory so we dont mess with the original data
basedir = '/media/parker/Data_Drive/400_manual_label'
base_image_dir = os.path.join(basedir, 'images')
base_label_dir = os.path.join(basedir, 'labels')

# new dir for images
new_dir = '/media/parker/Data_Drive/400_manual_label_aug/'
new_image_dir = os.path.join(new_dir, 'images')
new_label_dir = os.path.join(new_dir, 'labels')


# checking to see if the base directories exist
if not os.path.exists(base_image_dir):
    raise ValueError(f'Base image directory does not exist: {base_image_dir}')
if not os.path.exists(base_label_dir):
    raise ValueError(f'Base label directory does not exist: {base_label_dir}')
if not os.path.exists(new_image_dir):
    raise ValueError(f'New image directory does not exist: {new_image_dir}')
if not os.path.exists(new_label_dir):
    raise ValueError(f'New label directory does not exist: {new_label_dir}')

print(f'Base image directory: {base_image_dir}')
print(f'Base label directory: {base_label_dir}')
print(f'Augmented image directory: {new_image_dir}')
print(f'Augmented label directory: {new_label_dir}')
# Out:
# Base image directory: /media/parker/Data_Drive/400_manual_label/images
# Base label directory: /media/parker/Data_Drive/400_manual_label/labels
# Augmented image directory: /media/parker/Data_Drive/400_manual_label_aug/images
# Augmented label directory: /media/parker/Data_Drive/400_manual_label_aug/labels

# %%
image_files = [os.path.splitext(f)[0] for f in os.listdir(new_image_dir) if f.endswith('.png')]
label_files = [os.path.splitext(f)[0] for f in os.listdir(new_label_dir) if f.endswith('.txt')]

unmatched_images = [f + '.png' for f in image_files if f not in label_files]

if unmatched_images:
    print("\nThese image files do NOT have matching label files:")
    for file in unmatched_images:
        print(f" - {file}")
else:
    print("\n All PNG images have matching TXT label files.")
# Out:
#  All PNG images have matching TXT label files.

# %%
# rotate the cords
def rotate_coords(coords, angle):
    coords = np.array(coords).reshape(-1, 2)
    if angle == 90:
        coords = np.stack([1 - coords[:, 1], coords[:, 0]], axis=1)
    elif angle == 180:
        coords = 1 - coords
    elif angle == 270:
        coords = np.stack([coords[:, 1], 1 - coords[:, 0]], axis=1)
    return coords.flatten().tolist()

# %%
image_files = [f for f in os.listdir(new_image_dir) if f.endswith('.png')]

print(f"found {len(image_files)} images to process...\n")

for i, filename in enumerate(image_files, 1):
    base_name = os.path.splitext(filename)[0]
    image_path = os.path.join(new_image_dir, filename)
    label_path = os.path.join(new_label_dir, base_name + '.txt')

    # skip if label file does not exist
    if not os.path.exists(label_path):
        print(f"[{i}/{len(image_files)}] Skipping {filename} (label missing)")
        continue

    # load image and label file
    image = cv2.imread(image_path)
    with open(label_path, 'r') as f:
        lines = f.readlines()


    # rotate and save
    for angle in [90, 180, 270]:
        rotated_image = cv2.rotate(image, {
            90: cv2.ROTATE_90_CLOCKWISE,
            180: cv2.ROTATE_180,
            270: cv2.ROTATE_90_COUNTERCLOCKWISE
        }[angle])

        new_image_name = f"{base_name}_rot{angle}.png"
        new_image_path = os.path.join(new_image_dir, new_image_name)
        cv2.imwrite(new_image_path, rotated_image)

        # transform label coordinates
        new_lines = []
        for line in lines:
            parts = line.strip().split()
            class_id = parts[0]
            coords = list(map(float, parts[1:]))
            rotated_coords = rotate_coords(coords, angle)
            new_line = f"{class_id} " + " ".join(f"{c:.16f}" for c in rotated_coords)
            new_lines.append(new_line)

        new_label_name = f"{base_name}_rot{angle}.txt"
        new_label_path = os.path.join(new_label_dir, new_label_name)
        with open(new_label_path, 'w') as f:
            f.write("\n".join(new_lines))

    print(f"[{i}/{len(image_files)}]  {filename} processed")

print(" all images augmented successfully")
# Out:
# found 430 images to process...
#
# [1/430]  000f0ded-image_0270.png processed
# [2/430]  0056e591-image_0351.png processed
# [3/430]  00b2e674-image_0020.png processed
# [4/430]  00d033db-image_0325.png processed
# [5/430]  01319069-image_0282.png processed
# [6/430]  01471794-image_0360.png processed
# [7/430]  01bce3f0-image_0274.png processed
# [8/430]  02cbece9-image_0326.png processed
# [9/430]  036262f4-image_0231.png processed
# [10/430]  03a87745-image_0312.png processed
# [11/430]  04a52baa-image_0108.png processed
# [12/430]  04d8e746-image_0387.png processed
# [13/430]  04ec2875-image_0375.png processed
# [14/430]  055cade5-image_0400.png processed
# [15/430]  057c31aa-image_0216.png processed
# [16/430]  058658e0-image_0283.png processed
# [17/430]  07a86152-image_0138.png processed
# [18/430]  08e4458a-image_0404.png processed
# [19/430]  0a06bd94-image_0209.png processed
# [20/430]  0c7e4058-image_0086.png processed
# [21/430]  0cb73b23-image_0328.png processed
# [22/430]  0debe134-image_0229.png processed
# [23/430]  0ef55c51-image_0094.png processed
# [24/430]  0f3a33bc-image_0070.png processed
# [25/430]  0f498e47-image_0349.png processed
# [26/430]  104fcbc6-image_0116.png processed
# [27/430]  11e62320-image_0166.png processed
# [28/430]  11fb0803-image_0188.png processed
# [29/430]  130abd66-image_0204.png processed
# [30/430]  14a0683d-image_0213.png processed
# [31/430]  14fcded9-image_0122.png processed
# [32/430]  153b01c4-image_0075.png processed
# [33/430]  1656b319-image_0285.png processed
# [34/430]  16966097-image_0314.png processed
# [35/430]  1712e749-image_0190.png processed
# [36/430]  18471a95-image_0206.png processed
# [37/430]  189ed53b-image_0080.png processed
# [38/430]  18dde5f8-image_0161.png processed
# [39/430]  1a0200c5-image_0200.png processed
# [40/430]  1a995278-image_0333.png processed
# [41/430]  1c1a64b8-image_0026.png processed
# [42/430]  1c417ad6-image_0074.png processed
# [43/430]  1c666369-image_0010.png processed
# [44/430]  1d51d714-image_0174.png processed
# [45/430]  1e517ee4-image_0128.png processed
# [46/430]  1e7200fe-image_0063.png processed
# [47/430]  1ea33d1b-image_0180.png processed
# [48/430]  1fef2e09-image_0162.png processed
# [49/430]  20815fe5-image_0047.png processed
# [50/430]  20b401a1-image_0240.png processed
# [51/430]  2119c135-image_0099.png processed
# [52/430]  218f2396-image_0163.png processed
# [53/430]  2284341c-image_0109.png processed
# [54/430]  228711c4-image_0303.png processed
# [55/430]  22ab3549-image_0131.png processed
# [56/430]  22fd16cc-image_0014.png processed
# [57/430]  231a2fe3-image_0191.png processed
# [58/430]  2389c20e-image_0257.png processed
# [59/430]  23bfc84f-image_0239.png processed
# [60/430]  248b3526-image_0145.png processed
# [61/430]  252698b7-image_0354.png processed
# [62/430]  2574e7d8-image_0366.png processed
# [63/430]  27050f23-image_0275.png processed
# [64/430]  274f09e0-image_0407.png processed
# [65/430]  27ccb10d-image_0317.png processed
# [66/430]  28466e87-image_0098.png processed
# [67/430]  2988a249-image_0297.png processed
# [68/430]  2b5b1d6c-image_0332.png processed
# [69/430]  2d108014-image_0208.png processed
# [70/430]  2d3427e0-image_0176.png processed
# [71/430]  2eea0718-image_0256.png processed
# [72/430]  2f06f74a-image_0324.png processed
# [73/430]  307a6366-image_0062.png processed
# [74/430]  32bd67a2-image_0342.png processed
# [75/430]  336ae5ca-image_0368.png processed
# [76/430]  342007b2-image_0226.png processed
# [77/430]  3599ad04-image_0315.png processed
# [78/430]  35b7b46e-image_0104.png processed
# [79/430]  365fdddf-image_0330.png processed
# [80/430]  36c0ab89-image_0168.png processed
# [81/430]  370125d0-image_0126.png processed
# [82/430]  381da87c-image_0403.png processed
# [83/430]  38954658-image_0391.png processed
# [84/430]  39a9024a-image_0085.png processed
# [85/430]  39efcad6-image_0224.png processed
# [86/430]  39f0acca-image_0260.png processed
# [87/430]  3b2dcb6a-image_0238.png processed
# [88/430]  3d2cdbec-image_0118.png processed
# [89/430]  3d3c2f1f-image_0087.png processed
# [90/430]  3d7fe879-image_0377.png processed
# [91/430]  3dca1d9e-image_0169.png processed
# [92/430]  3e14820e-image_0347.png processed
# [93/430]  3eb40fc3-image_0135.png processed
# [94/430]  3ed10be2-image_0182.png processed
# [95/430]  3f652bf7-image_0082.png processed
# [96/430]  3fb63288-image_0033.png processed
# [97/430]  4020f770-image_0060.png processed
# [98/430]  40225b8d-image_0125.png processed
# [99/430]  4050eb7e-image_0301.png processed
# [100/430]  40f03cec-image_0217.png processed
# [101/430]  40f9718a-image_0183.png processed
# [102/430]  4112ba23-image_0065.png processed
# [103/430]  418c39b8-image_0037.png processed
# [104/430]  41e3eab1-image_0028.png processed
# [105/430]  450cec9f-image_0356.png processed
# [106/430]  45c508fd-image_0202.png processed
# [107/430]  46205ab4-image_0029.png processed
# [108/430]  468f6943-image_0073.png processed
# [109/430]  469a600c-image_0313.png processed
# [110/430]  46cff31a-image_0117.png processed
# [111/430]  46eada64-image_0079.png processed
# [112/430]  472eec07-image_0041.png processed
# [113/430]  485325f7-image_0113.png processed
# [114/430]  4917b13e-image_0235.png processed
# [115/430]  4981398e-image_0259.png processed
# [116/430]  49d9854a-image_0121.png processed
# [117/430]  4a09acb1-image_0052.png processed
# [118/430]  4a0b3b8e-image_0302.png processed
# [119/430]  4af6eac5-image_0214.png processed
# [120/430]  4b3f1b21-image_0039.png processed
# [121/430]  4b3fc6be-image_0100.png processed
# [122/430]  4bf24f6a-image_0384.png processed
# [123/430]  4c0c9a37-image_0233.png processed
# [124/430]  4cffe765-image_0376.png processed
# [125/430]  4e6c1830-image_0179.png processed
# [126/430]  5066b111-image_0186.png processed
# [127/430]  509538a3-image_0068.png processed
# [128/430]  5301f9b7-image_0127.png processed
# [129/430]  53a4409e-image_0111.png processed
# [130/430]  53e5c55f-image_0072.png processed
# [131/430]  54046b3c-image_0300.png processed
# [132/430]  5452c914-image_0218.png processed
# [133/430]  547cc01b-image_0022.png processed
# [134/430]  55c44d5e-image_0156.png processed
# [135/430]  563031aa-image_0251.png processed
# [136/430]  56ed530c-image_0120.png processed
# [137/430]  57500b71-image_0130.png processed
# [138/430]  575df209-image_0059.png processed
# [139/430]  58268379-image_0011.png processed
# [140/430]  5833876b-image_0243.png processed
# [141/430]  58b03af4-image_0081.png processed
# [142/430]  58bda577-image_0096.png processed
# [143/430]  59bf9726-image_0284.png processed
# [144/430]  5a1787cf-image_0371.png processed
# [145/430]  5ae9d44d-image_0394.png processed
# [146/430]  5bc9f39a-image_0159.png processed
# [147/430]  5e591c92-image_0103.png processed
# [148/430]  5e76261b-image_0132.png processed
# [149/430]  6033406c-image_0290.png processed
# [150/430]  60738b08-image_0215.png processed
# [151/430]  6117fd38-image_0038.png processed
# [152/430]  61d63cda-image_0277.png processed
# [153/430]  6271f4c7-image_0160.png processed
# [154/430]  62dd032e-image_0262.png processed
# [155/430]  62f2bb94-image_0245.png processed
# [156/430]  6433a0ab-image_0345.png processed
# [157/430]  64b902bf-image_0019.png processed
# [158/430]  64f65b18-image_0236.png processed
# [159/430]  65140348-image_0083.png processed
# [160/430]  65dc08d7-image_0228.png processed
# [161/430]  670afa78-image_0018.png processed
# [162/430]  67d8681d-image_0340.png processed
# [163/430]  67e2a0ee-image_0036.png processed
# [164/430]  685d74bb-image_0310.png processed
# [165/430]  68a98884-image_0374.png processed
# [166/430]  68d7f5a6-image_0273.png processed
# [167/430]  68db2907-image_0199.png processed
# [168/430]  69772336-image_0258.png processed
# [169/430]  6aa06af4-image_0353.png processed
# [170/430]  6b50e134-image_0107.png processed
# [171/430]  6c342f30-image_0061.png processed
# [172/430]  6c80f750-image_0396.png processed
# [173/430]  6e994ecb-image_0350.png processed
# [174/430]  6ea3fab6-image_0389.png processed
# [175/430]  6f8c03f8-image_0211.png processed
# [176/430]  71830ea2-image_0195.png processed
# [177/430]  721e2d6c-image_0034.png processed
# [178/430]  75bc7b55-image_0253.png processed
# [179/430]  76b21a99-image_0097.png processed
# [180/430]  780fe08e-image_0336.png processed
# [181/430]  7878d10e-image_0405.png processed
# [182/430]  79061cee-image_0385.png processed
# [183/430]  793f0c3c-image_0193.png processed
# [184/430]  7acba102-image_0246.png processed
# [185/430]  7b4d6642-image_0013.png processed
# [186/430]  7b5e37be-image_0203.png processed
# [187/430]  7c641103-image_0212.png processed
# [188/430]  7ced968d-image_0067.png processed
# [189/430]  7d40f7dd-image_0015.png processed
# [190/430]  7e26d0f9-image_0171.png processed
# [191/430]  7e986f1d-image_0076.png processed
# [192/430]  7eb1ca8d-image_0030.png processed
# [193/430]  7ee3d16a-image_0320.png processed
# [194/430]  7f0ca9ef-image_0158.png processed
# [195/430]  81dac964-image_0355.png processed
# [196/430]  81ef3eba-image_0181.png processed
# [197/430]  82711380-image_0071.png processed
# [198/430]  847667f7-image_0055.png processed
# [199/430]  850a1cff-image_0170.png processed
# [200/430]  851ea90e-image_0194.png processed
# [201/430]  86649cfc-image_0254.png processed
# [202/430]  86d757d5-image_0261.png processed
# [203/430]  893d5892-image_0232.png processed
# [204/430]  894ec49a-image_0144.png processed
# [205/430]  8951a445-image_0012.png processed
# [206/430]  89b18581-image_0339.png processed
# [207/430]  89f0e232-image_0069.png processed
# [208/430]  8a830c9b-image_0139.png processed
# [209/430]  8c33e2ae-image_0402.png processed
# [210/430]  8c449162-image_0280.png processed
# [211/430]  8e46c1a6-image_0264.png processed
# [212/430]  8e5de2a2-image_0268.png processed
# [213/430]  8eb35430-image_0192.png processed
# [214/430]  90d98a04-image_0408.png processed
# [215/430]  916b85c9-image_0102.png processed
# [216/430]  9174f55e-image_0095.png processed
# [217/430]  91f46751-image_0295.png processed
# [218/430]  929e985a-image_0379.png processed
# [219/430]  9390fa37-image_0051.png processed
# [220/430]  94cbaa09-image_0220.png processed
# [221/430]  954f3491-image_0399.png processed
# [222/430]  9597c831-image_0123.png processed
# [223/430]  959da6fb-image_0323.png processed
# [224/430]  96487b5d-image_0084.png processed
# [225/430]  9670aa2a-image_0187.png processed
# [226/430]  97dabac7-image_0133.png processed
# [227/430]  97fa7a8a-image_0155.png processed
# [228/430]  98247e88-image_0153.png processed
# [229/430]  983085eb-image_0089.png processed
# [230/430]  98517a9d-image_0331.png processed
# [231/430]  9880ba74-image_0269.png processed
# [232/430]  9895deb8-image_0219.png processed
# [233/430]  98ce9a2f-image_0066.png processed
# [234/430]  996e1bff-image_0365.png processed
# [235/430]  99a3f9e8-image_0175.png processed
# [236/430]  9a1fa908-image_0369.png processed
# [237/430]  9a2b5ad9-image_0344.png processed
# [238/430]  9b3ccef3-image_0337.png processed
# [239/430]  9b489669-image_0050.png processed
# [240/430]  9bea6988-image_0279.png processed
# [241/430]  9c1a6a58-image_0409.png processed
# [242/430]  9c479cf0-image_0358.png processed
# [243/430]  9f03eb16-image_0064.png processed
# [244/430]  9f559609-image_0049.png processed
# [245/430]  a0a7efa4-image_0266.png processed
# [246/430]  a1c3c6d6-image_0167.png processed
# [247/430]  a252a99d-image_0249.png processed
# [248/430]  a2726b9c-image_0288.png processed
# [249/430]  a27742fa-image_0077.png processed
# [250/430]  a285aedc-image_0241.png processed
# [251/430]  a2d1c35e-image_0247.png processed
# [252/430]  a35acbdf-image_0210.png processed
# [253/430]  a5ea5fd0-image_0357.png processed
# [254/430]  a6a65aee-image_0242.png processed
# [255/430]  a704ab9a-image_0185.png processed
# [256/430]  a70575a1-image_0178.png processed
# [257/430]  a708eb37-image_0271.png processed
# [258/430]  a725347f-image_0298.png processed
# [259/430]  a78b3c4b-image_0124.png processed
# [260/430]  a8ccc303-image_0046.png processed
# [261/430]  a8ef916e-image_0129.png processed
# [262/430]  a9f305fc-image_0088.png processed
# [263/430]  aa254d27-image_0091.png processed
# [264/430]  aa45f937-image_0057.png processed
# [265/430]  aa73c0c4-image_0363.png processed
# [266/430]  aa91d829-image_0230.png processed
# [267/430]  aae35f87-image_0395.png processed
# [268/430]  abc458bd-image_0198.png processed
# [269/430]  abcbeed5-image_0223.png processed
# [270/430]  ac29c1fc-image_0346.png processed
# [271/430]  ac2d07dc-image_0114.png processed
# [272/430]  ac697174-image_0140.png processed
# [273/430]  ac94c75c-image_0025.png processed
# [274/430]  ad47dd8a-image_0272.png processed
# [275/430]  adee94ec-image_0056.png processed
# [276/430]  ae26ddd1-image_0045.png processed
# [277/430]  af44fec7-image_0361.png processed
# [278/430]  b00ff8ef-image_0338.png processed
# [279/430]  b158746c-image_0390.png processed
# [280/430]  b175d6fe-image_0307.png processed
# [281/430]  b37640e5-image_0393.png processed
# [282/430]  b39f2732-image_0042.png processed
# [283/430]  b5e8ef92-image_0252.png processed
# [284/430]  b7067856-image_0134.png processed
# [285/430]  b738c2b0-image_0164.png processed
# [286/430]  b83f01aa-image_0054.png processed
# [287/430]  b9d72fcf-image_0388.png processed
# [288/430]  b9e4eb7c-image_0373.png processed
# [289/430]  b9f7cd86-image_0154.png processed
# [290/430]  ba0162f8-image_0291.png processed
# [291/430]  ba247246-image_0101.png processed
# [292/430]  bae8ca18-image_0372.png processed
# [293/430]  bb527018-image_0112.png processed
# [294/430]  bb753ca8-image_0343.png processed
# [295/430]  bbc9371d-image_0105.png processed
# [296/430]  bbdecde8-image_0017.png processed
# [297/430]  be5ea099-image_0157.png processed
# [298/430]  bec67ba2-image_0265.png processed
# [299/430]  c1347f33-image_0304.png processed
# [300/430]  c3a2ae57-image_0248.png processed
# [301/430]  c3e4e6b5-image_0292.png processed
# [302/430]  c40ea56c-image_0267.png processed
# [303/430]  c44b26d7-image_0296.png processed
# [304/430]  c67c6c39-image_0364.png processed
# [305/430]  c6a81d8d-image_0392.png processed
# [306/430]  c78b1e42-image_0142.png processed
# [307/430]  c8626052-image_0137.png processed
# [308/430]  c9e928e3-image_0308.png processed
# [309/430]  cac7ec6c-image_0201.png processed
# [310/430]  caca289e-image_0401.png processed
# [311/430]  cafa708e-image_0362.png processed
# [312/430]  cb1ff9a4-image_0335.png processed
# [313/430]  cb9d20e3-image_0016.png processed
# [314/430]  cba7b575-image_0286.png processed
# [315/430]  cc79cb0d-image_0165.png processed
# [316/430]  cce2fade-image_0316.png processed
# [317/430]  cfe52a2b-image_0149.png processed
# [318/430]  d0914deb-image_0322.png processed
# [319/430]  d0b28a1d-image_0341.png processed
# [320/430]  d0ece644-image_0287.png processed
# [321/430]  d10f880c-image_0293.png processed
# [322/430]  d12a290a-image_0023.png processed
# [323/430]  d2fd7d4d-image_0136.png processed
# [324/430]  d3511f5d-image_0276.png processed
# [325/430]  d39c4b67-image_0244.png processed
# [326/430]  d3d02cc2-image_0141.png processed
# [327/430]  d3deadec-image_0078.png processed
# [328/430]  d4bfde86-image_0406.png processed
# [329/430]  d653efec-image_0289.png processed
# [330/430]  d662fa55-image_0378.png processed
# [331/430]  d67dee96-image_0370.png processed
# [332/430]  d68c5cab-image_0306.png processed
# [333/430]  d82c40ab-image_0281.png processed
# [334/430]  d874cc5c-image_0237.png processed
# [335/430]  d8999711-image_0177.png processed
# [336/430]  d8b5547b-image_0225.png processed
# [337/430]  d8dde306-image_0386.png processed
# [338/430]  da05a238-image_0234.png processed
# [339/430]  da1a2d0b-image_0115.png processed
# [340/430]  db155590-image_0205.png processed
# [341/430]  db4df35e-image_0058.png processed
# [342/430]  db71aaa0-image_0196.png processed
# [343/430]  dba861b9-image_0092.png processed
# [344/430]  dc653116-image_0383.png processed
# [345/430]  dca40b79-image_0053.png processed
# [346/430]  dca6e87c-image_0184.png processed
# [347/430]  dcdac81b-image_0367.png processed
# [348/430]  dcf47165-image_0227.png processed
# [349/430]  dd66cabe-image_0398.png processed
# [350/430]  deaf4899-image_0189.png processed
# [351/430]  dfde1c34-image_0040.png processed
# [352/430]  e0e637e2-image_0381.png processed
# [353/430]  e160f0c0-image_0152.png processed
# [354/430]  e1f0645d-image_0380.png processed
# [355/430]  e2d04c64-image_0173.png processed
# [356/430]  e397bbb7-image_0027.png processed
# [357/430]  e42e15ed-image_0031.png processed
# [358/430]  e4f7bf95-image_0021.png processed
# [359/430]  e5691589-image_0032.png processed
# [360/430]  e5ae2d41-image_0255.png processed
# [361/430]  e5f0d122-image_0359.png processed
# [362/430]  e6ebf66c-image_0329.png processed
# [363/430]  e73cd832-image_0143.png processed
# [364/430]  e8245ea7-image_0319.png processed
# [365/430]  e82b0eb8-image_0222.png processed
# [366/430]  e8ab4753-image_0119.png processed
# [367/430]  e96ec6a8-image_0197.png processed
# [368/430]  e9846637-image_0348.png processed
# [369/430]  ec6d163e-image_0172.png processed
# [370/430]  ec877fb9-image_0278.png processed
# [371/430]  ec88e362-image_0043.png processed
# [372/430]  ed51acc4-image_0148.png processed
# [373/430]  edb3b1c7-image_0318.png processed
# [374/430]  eddd7f24-image_0090.png processed
# [375/430]  ef25476c-image_0150.png processed
# [376/430]  f0afdf7e-image_0093.png processed
# [377/430]  f190d33f-image_0321.png processed
# [378/430]  f23a7e91-image_0221.png processed
# [379/430]  f23e61cf-image_0397.png processed
# [380/430]  f274a106-image_0299.png processed
# [381/430]  f2f2a7bd-image_0151.png processed
# [382/430]  f3240c86-image_0024.png processed
# [383/430]  f3378d88-image_0334.png processed
# [384/430]  f389cb10-image_0327.png processed
# [385/430]  f49edca9-image_0035.png processed
# [386/430]  f524f120-image_0147.png processed
# [387/430]  f5b8d1fa-image_0382.png processed
# [388/430]  f67b37c7-image_0250.png processed
# [389/430]  f9162021-image_0309.png processed
# [390/430]  f95239ae-image_0294.png processed
# [391/430]  f97ef6c5-image_0106.png processed
# [392/430]  f9ed3194-image_0146.png processed
# [393/430]  fa423ae1-image_0048.png processed
# [394/430]  faa7ef1f-image_0311.png processed
# [395/430]  fb794cce-image_0207.png processed
# [396/430]  fe348382-image_0305.png processed
# [397/430]  fe5de9e8-image_0263.png processed
# [398/430]  feaf95c8-image_0352.png processed
# [399/430]  fec18d18-image_0110.png processed
# [400/430]  ff0a0332-image_0044.png processed
# [401/430]  0aed85bb-image_10007.png processed
# [402/430]  0b7d80b9-image_9983.png processed
# [403/430]  2fdc3738-image_10001.png processed
# [404/430]  3ea442e6-image_10009.png processed
# [405/430]  4ef098cc-image_10002.png processed
# [406/430]  5b9e4b1c-image_9980.png processed
# [407/430]  5c6a0169-image_10006.png processed
# [408/430]  6bac0a22-image_9996.png processed
# [409/430]  6e1aa852-image_9985.png processed
# [410/430]  7c6ae90a-image_9993.png processed
# [411/430]  9d186e99-image_9986.png processed
# [412/430]  20aba137-image_9982.png processed
# [413/430]  30a5a730-image_9991.png processed
# [414/430]  42c68dec-image_9999.png processed
# [415/430]  634e9313-image_10005.png processed
# [416/430]  907c036a-image_9987.png processed
# [417/430]  2830ad67-image_9988.png processed
# [418/430]  02957cb9-image_9995.png processed
# [419/430]  5823ca72-image_9984.png processed
# [420/430]  471833ae-image_9990.png processed
# [421/430]  14201775-image_10000.png processed
# [422/430]  36954249-image_9994.png processed
# [423/430]  a5174bdc-image_9989.png processed
# [424/430]  af01a4b0-image_9981.png processed
# [425/430]  b855a138-image_10003.png processed
# [426/430]  b5238923-image_9998.png processed
# [427/430]  bddc4bf4-image_9997.png processed
# [428/430]  c7fbaade-image_9992.png processed
# [429/430]  c8dc4253-image_10008.png processed
# [430/430]  d538458f-image_10004.png processed
#  all images augmented successfully
